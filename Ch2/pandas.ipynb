# %% [markdown]
# Pandas 範例程式碼

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /opt/homebrew/anaconda3/lib/python3.9/site-packages (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.20.0 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from pandas) (1.21.5)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
import pandas as pd

# %%
df = pd.DataFrame ([[170, 60],
			[164, 50],
			[180, 70]])
df
# Out:
#      0   1
# 0  170  60
# 1  164  50
# 2  180  70

# %%
import pandas as pd
df = pd.DataFrame ([[170, 60],
			[164, 50],
			[180, 70]], index=['A','B','C'], columns = ["height","weight"])
df
# Out:
#    height  weight
# A     170      60
# B     164      50
# C     180      70

# %%
df.values
# Out:
# array([[170,  60],
#        [164,  50],
#        [180,  70]])

# %%
df['height']
# Out:
# A    170
# B    164
# C    180
# Name: height, dtype: int64

# %%
df[df['height']>175]
# Out:
#    height  weight
# C     180      70

# %%
print(df.loc["A","height"])
# Out:
# 170

# %%
print(df.loc["A",["weight","height"]])
# Out:
# weight     60
# height    170
# Name: A, dtype: int64

# %%
print(df.iloc[2,0])
# Out:
# 180

# %%
df.iloc[2,[0,1]]
# Out:
# height    180
# weight     70
# Name: C, dtype: int64

# %%
df
# Out:
#    height  weight
# A     170      60
# B     164      50
# C     180      70

# %%
print("Before:\n ", df)
df.loc["A","height"]=172
print("After:\n ",df)
# Out:
# Before:
#      height  weight
# A     170      60
# B     164      50
# C     180      70
# After:
#      height  weight
# A     172      60
# B     164      50
# C     180      70

# %%
print(df)
df.sort_values(by="height",ascending=False)
print(df)
# Out:
#    height  weight
# A     172      60
# B     164      50
# C     180      70
#    height  weight
# A     172      60
# B     164      50
# C     180      70

# %%
print(df)
series = pd.Series({"height": 180,"weight": 60},name="D")
df = df.append(series)
print(df)
# Out:
#    height  weight
# A     172      60
# B     164      50
# C     180      70
#    height  weight
# A     172      60
# B     164      50
# C     180      70
# D     180      60
# /var/folders/kv/hp2jg4m50dxbsyw1v45hqpw80000gn/T/ipykernel_98134/2417882534.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(series)

# %%
print(df)
df = df.drop(["A","C"])
print(df)
# Out:
#    height  weight
# A     172      60
# B     164      50
# C     180      70
# D     180      60
#    height  weight
# B     164      50
# D     180      60

# %%
df = pd.DataFrame ([[170, 60],
			[164, 50],
			[180, 70]], index=['A','B','C'], columns = ["height","weight"])

# %%
print(df)
df = df.drop(["height"],axis=1)
print(df)
# Out:
#    height  weight
# A     170      60
# B     164      50
# C     180      70
#    weight
# A      60
# B      50
# C      70

# %%
# !pip install names
# Out:
# Requirement already satisfied: names in /opt/homebrew/anaconda3/lib/python3.9/site-packages (0.3.0)
#
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: pip install --upgrade pip

# %%
df = pd.DataFrame ([[170, 60],
			[164, 50],
			[180, 70]], index=['A','B','C'], columns = ["height","weight"])
import random
import names
for i in range(100):
    new = pd.DataFrame({'height': 160+random.randint(0,20), 'weight': 50+random.randint(0,20)}, index= [names.get_first_name()])
    df = pd.concat([df, new]) # 由於 append 將在未來的版本被廢除，因此此處使用concat的方式來新增資料。
print(df)
df = df.drop(["A","B","C"])
print(df)
# Out:
#          height  weight
# A           170      60
# B           164      50
# C           180      70
# Erica       172      54
# Jose        165      61
# ...         ...     ...
# George      173      67
# Thomas      163      55
# Joseph      177      54
# Cindy       166      52
# Jerrold     175      60
#
# [103 rows x 2 columns]
#          height  weight
# Erica       172      54
# Jose        165      61
# Ruth        171      62
# Ty          166      57
# Dorothy     172      67
# ...         ...     ...
# George      173      67
# Thomas      163      55
# Joseph      177      54
# Cindy       166      52
# Jerrold     175      60
#
# [100 rows x 2 columns]

# %%
print(df)
print(df.head(10))
# Out:
#          height  weight
# Erica       172      54
# Jose        165      61
# Ruth        171      62
# Ty          166      57
# Dorothy     172      67
# ...         ...     ...
# George      173      67
# Thomas      163      55
# Joseph      177      54
# Cindy       166      52
# Jerrold     175      60
#
# [100 rows x 2 columns]
#          height  weight
# Erica       172      54
# Jose        165      61
# Ruth        171      62
# Ty          166      57
# Dorothy     172      67
# Ricky       173      70
# Suzanne     177      58
# Casey       168      53
# Natasha     169      62
# Donald      172      58

# %%
print(df)
print(df.tail(10))
# Out:
#          height  weight
# Erica       172      54
# Jose        165      61
# Ruth        171      62
# Ty          166      57
# Dorothy     172      67
# ...         ...     ...
# George      173      67
# Thomas      163      55
# Joseph      177      54
# Cindy       166      52
# Jerrold     175      60
#
# [100 rows x 2 columns]
#          height  weight
# Shirley     168      53
# Julius      169      68
# Michael     162      57
# Malissa     172      54
# Ramona      165      60
# George      173      67
# Thomas      163      55
# Joseph      177      54
# Cindy       166      52
# Jerrold     175      60

# %% [markdown]
# 小試身手練習題

# %%
df = pd.DataFrame ([[170, 16],
			[164, 25],
			[180, 17], [167, 19]], index=['Allen','Ken','John', 'Jason'], columns = ["height","age"])

# %%
df
# Out:
#        height  age
# Allen     170   16
# Ken       164   25
# John      180   17
# Jason     167   19

# %%
print(df.iloc[1,0])
print("-----")
print(df.loc["Ken","height"])
print("-----")
print(df.loc[:,"height"])
# Out:
# 164
# -----
# 164
# -----
# Allen    170
# Ken      164
# John     180
# Jason    167
# Name: height, dtype: int64
